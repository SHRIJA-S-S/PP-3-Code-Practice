# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRIJA-S-S/PP-3-Code-Practice/blob/main/pp3oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BankAccount:
    def __init__(self, balance, account_holder):
        self.__balance = balance
        self._account_holder = account_holder

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Balance insufficient")

    def get_balance(self):
        return self.__balance


class SavingsAccount(BankAccount):
    def __init__(self, balance, account_holder, interestrate):
        super().__init__(balance, account_holder)
        self.interestrate = interestrate
    def withdraw(self, amount):
        if amount > 20000:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("minimum is $20000")

    def get_interestrate(self):
        return self.interestrate

bankaccount = BankAccount(1000, "hari")
bankaccount.deposit(500)
print(bankaccount.get_balance())

savingsaccount = SavingsAccount(1000, "hari", 7.7)
savingsaccount.withdraw(500)
print(accc.get_interestrate())
# Out:
# Deposited $500. New balance: $1500
# 1500
# minimum is $20000
# 7.7

# %%
class Employee:
    def __init__(self, name, empid):
        self.name = name
        self.empid = empid

    def calculate_salary(self):
        print("Salary calculation not defined")

    def display_details(self):
        print(f"Name: {self.name}, Employee ID: {self.empid}")


class FullTimeEmployee(Employee):
    def __init__(self, name, empid, monthly_salary):
        super().__init__(name, empid)
        self.monthly_salary = monthly_salary

    def calculate_salary(self):
        return self.monthly_salary


class PartTimeEmployee(Employee):
    def __init__(self, name, empid, rate_per_hour, hours_worked):
        super().__init__(name, empid)
        self.rate_per_hour = rate_per_hour
        self.hours_worked = hours_worked

    def calculate_salary(self):
        return self.rate_per_hour * self.hours_worked


full = FullTimeEmployee("hari", 3, 10000)
part = PartTimeEmployee("hari", 14, 200, 10)

full.display_details()
print("Salary:", full.calculate_salary())

part.display_details()
print("Salary:", part.calculate_salary())
# Out:
# Name: hari, Employee ID: 3
# Salary: 10000
# Name: hari, Employee ID: 14
# Salary: 2000
