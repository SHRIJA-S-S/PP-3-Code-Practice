# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRIJA-S-S/PP-3-Code-Practice/blob/main/pp3dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
days=set({"monday","tuesday","wednesday","thursday","saturday","sunday"})
print(days)
print(type(days))

for i in days:
  print(i)

#mutable
#set2={1,2,3,["javatpoint",4]} #so there is list inside a set
#print(set2)

set4=set()           #emnpty set
print(type(set4))

set5={1,2,4,9,7,3,2}
print(set5)  #returns only unique elements
print(len(set5))

mon=set(["jan","feb","mar","april","may","june","july","november"])
print(mon)

mon.add("dec")
print(mon)

mon.discard("dec")
print(mon)

mon.remove("jan")
print(mon)
mon.discard("jan")    #it doesnot throw error even though no jan in list

mon.pop();
print(mon)
for i in mon:
  print(i)

#mon.clear()        clears the full set

days=set(["monday","tuesday","wednesday","thursday"])
dayss=set(["thursday","saturday","sunday"])
print(days|dayss)           #union using '|' symbol
print(days.union(dayss))    #union using union function
print(days&dayss)           #union using '&'symbol and this gives the same element in both the sets
commonele=days.union(days,dayss)
print(commonele)

#intersection
print(days.intersection(dayss))
print(days&dayss)

daysss=days.intersection(dayss)
print(daysss)

a={"dar","cow","sha"}
b={"sha","shr","sat"}
c={"sha","sag","man"}

a.intersection_update(b,c) #updated with one another
print(a)

print(dayss-daysss)

print(days.difference(dayss))

a={1,2,4,5,6}
b={2,5,9,4,7}
c=a^b
print(c)   #symmetric differnce using'^'

c.symmetric_difference(b)
print(c)    #symmteric differnce using the function

a.symmetric_difference_update(b)
print(a)

print(days>dayss)
print(days.issuperset(dayss))
print(days<dayss)
print(days.issubset(dayss))
# Out:
# {'tuesday', 'saturday', 'monday', 'wednesday', 'sunday', 'thursday'}
# <class 'set'>
# tuesday
# saturday
# monday
# wednesday
# sunday
# thursday
# <class 'set'>
# {1, 2, 3, 4, 7, 9}
# 6
# {'july', 'june', 'november', 'april', 'mar', 'may', 'feb', 'jan'}
# {'july', 'june', 'november', 'april', 'mar', 'may', 'feb', 'dec', 'jan'}
# {'july', 'june', 'november', 'april', 'mar', 'may', 'feb', 'jan'}
# {'july', 'june', 'november', 'april', 'mar', 'may', 'feb'}
# {'june', 'november', 'april', 'mar', 'may', 'feb'}
# june
# november
# april
# mar
# may
# feb
# {'tuesday', 'saturday', 'monday', 'wednesday', 'sunday', 'thursday'}
# {'tuesday', 'saturday', 'monday', 'wednesday', 'sunday', 'thursday'}
# {'thursday'}
# {'tuesday', 'saturday', 'monday', 'wednesday', 'sunday', 'thursday'}
# {'thursday'}
# {'thursday'}
# {'thursday'}
# {'sha'}
# {'saturday', 'sunday'}
# {'tuesday', 'wednesday', 'monday'}
# {1, 6, 7, 9}
# {1, 6, 7, 9}
# {1, 6, 7, 9}
# False
# False
# False
# False
