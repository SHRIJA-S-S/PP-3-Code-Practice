# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRIJA-S-S/PP-3-Code-Practice/blob/main/pp3constructor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class circle():
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    def circum(self):
        return 2*3.14*self.radius
pp=circle(25)
print(pp.area())
print(pp.circum())
# Out:
# 1962.5
# 157.0

# %%
class Vehicle():
    def __init__(self,name,colour,worth):
        self.name=name
        self.colour=colour
        self.worth=worth
    def det(self):
        print("car=",self.name,self.colour,self.worth)
car1=Vehicle("BMW","red","6000000")
car2=Vehicle("ferari","black","2000000")

car1.det()
# Out:
# car= BMW red 6000000

# %%
class temp():
    def tofar(self,celcius):
        self.celcius=celcius
        return (self.celcius*(9/5))+32
    def tocel(self,faren):
        self.faren=faren
        return (self.faren-32)*(5/9)
tem=temp()
print(tem.tocel(104))
# Out:
# 40.0

# %%
class marksheet():
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
    def display(self):
        print("name=",self.name)
        print("rollno=",self.rollno)
    def setage(self,age):
        self.age=age
    def setmark(self,mark):
        self.mark=mark

marks=marksheet("john","2")
marks.display()
# Out:
# name= john
# rollno= 2

# %%
class triangle():
    def __init__(self,angle1,angle2,angle3):
        self.angle1=angle1
        self.angle2=angle2
        self.angle3=angle3
    no_of_slides=3;
    def check(self):
        if self.angle1+self.angle2+self.angle3==180:
          return True
        else:
          return False
tri=triangle(60,60,60)
print(tri.no_of_slides)
print(tri.check())
# Out:
# 3
# True

# %%
class song():
    def __init__(self,lyrics):
        self.lyrics=lyrics
    def sing_me_a_song(self):
        for line in self.lyrics:
            print(line)
happy_day=song(["happy","birthday","to","you"])
print(happy_day.sing_me_a_song())
# Out:
# happy
# birthday
# to
# you
# None

# %%
class lunch():
    def __init__(self,menu):
        self.menu=menu
    def menu_p(self):
      if self.menu==menu1:
        print("menu is sandwich")
      elif self.menu==menu2:
        print("menu is pizza")
      else:
        print("menu is burger")
menu1="sandwich"
menu2="pizza"
menu3="burger"
my_order=lunch(menu3)
print(my_order.menu_p())
# Out:
# menu is burger
# None

# %%
class threeDObject():
  def __init__(self, x, y, z):
    self.x = x
    self.y = y
    self.z = z
  def rep(self):
    print(self.x, self.y, self.z)
gn_point=threeDObject(1,2,3)
gn_point.rep()
# Out:
# 1 2 3
